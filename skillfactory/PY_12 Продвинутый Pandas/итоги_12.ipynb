# %% [markdown]
# # Итоги модуля 12

# %%
import pandas as pd
import re

# %%
data = pd.read_csv('data/ratings_movies.csv')
display(data.head(5))

# %%
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
data['year_realese'] = data['title'].apply(get_year_release)
data.info()

# %%
mask= data['year_realese'] == 1999 
data[mask].groupby('title')['rating'].mean().sort_values()

# %%
mask1= data['year_realese'] == 2010
data[mask1].groupby('genres')['rating'].mean().sort_values()

# %%
data.groupby('userId')['genres'].nunique().sort_values(ascending=False)

# %%
data.groupby('userId')['rating'].agg(['mean','count']).sort_values(['count', 'mean'], ascending=[True, False])

# %%
mask_2018 = data['year_realese'] == 2018
data[mask_2018].groupby('genres')['rating'].agg(
    ['median', 'count']
).sort_values(['median', 'count'], ascending=[False, True])

# %%
data['date'] = pd.to_datetime(data['date'])
display(data.info())

# %%
data['year_rating'] = data['date'].dt.year
display(data)

# %%
analytic = data.pivot_table(
    values='rating',
    index='year_rating',
    columns='genres',
    aggfunc='mean',
    fill_value=0    
).round(2)
display(analytic)

# %%
orders_df = pd.read_csv('data/orders.csv', sep=';')
product_df = pd.read_csv('data/products.csv', sep=';')

# %%
merged = orders_df.merge(
    product_df,
    right_on='Product_ID',
    left_on='ID товара',
    how='left'
)

# %%
merged
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
merged[merged['Статус']=='Отменён']['Name']
# Out:
# 6    Носки беговые Camino
# Name: Name, dtype: object

# %%
merged['Profit'] = merged['Количество'] * merged['Price']
merged[merged['Оплачен']=='Да'].groupby('ID Покупателя')['Profit'].sum().sort_values
# Out:
# <bound method Series.sort_values of ID Покупателя
# 1        0.0
# 5    13043.0
# 7    17096.0
# 8     1344.0
# Name: Profit, dtype: float64>
